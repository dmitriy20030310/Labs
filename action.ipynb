# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv<2.2.0,>=2.0.0rc4
# !mim install mmdet<3.3.0,>=3.0.0
# !mim install mmpose
# Out:
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/index.html
# ...
# /bin/bash: line 1: 2.2.0,: No such file or directory
# /bin/bash: line 1: 3.3.0,: No such file or directory
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/index.html
# ...
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# Ignoring mmdet: markers 'extra == "mim"' don't match your environment
# Ignoring mmengine: markers 'extra == "mim"' don't match your environment
# ...

# %%
# !mim install "mmcv>=2.0.0rc4, <2.2.0"
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.4/471.4 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mmcv: filename=mmcv-2.1.0-cp310-cp310-linux_x86_64.whl size=38336388 sha256=eb72c829b7398044aa23f0fd214d1a784f78bed5d587bda7dc2ea509e63be885
#   Stored in directory: /root/.cache/pip/wheels/8b/09/35/94a7f7ba6a00e3810abd0492340e4cbba0ff3d443120a94120
# Successfully built mmcv
# ...

# %%
# !git clone https://github.com/open-mmlab/mmaction2.git
from google.colab import drive
drive.mount('/content/gdrive')
# %cd mmaction2
# !pip install -v -e .
# Out:
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 22864, done.
# remote: Total 22864 (delta 0), reused 0 (delta 0), pack-reused 22864 (from 1)
# Receiving objects: 100% (22864/22864), 69.62 MiB | 14.57 MiB/s, done.
# Resolving deltas: 100% (16120/16120), done.
# Mounted at /content/gdrive
# /content/mmaction2
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content/mmaction2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-ikmi0krs/mmaction2.egg-info
#   writing /tmp/pip-pip-egg-info-ikmi0krs/mmaction2.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-ikmi0krs/mmaction2.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-ikmi0krs/mmaction2.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-ikmi0krs/mmaction2.egg-info/top_level.txt
# ...

# %%
# !pip install moviepy
# !python tools/visualizations/browse_dataset.py \
    configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    browse_out --mode pipeline
# Out:
# ...
# [                                                  ] 0/42, elapsed: 0s, ETA:08/09 13:00:19 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/09 13:00:19 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ...

# %%
# !pip install timm
# !python tools/visualizations/vis_scheduler.py \
    configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 15.8 MB/s eta 0:00:00
# ...
# python3: can't open file '/content/tools/visualizations/vis_scheduler.py': [Errno 2] No such file or directory

# %%
! CUDA_VISIBLE_DEVICES=-1 python tools/train.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py
# Out:
# 08/09 13:23:09 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: False
#     MUSA available: False
#     numpy_random_seed: 483509397
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
# ...

# %%
# !python tools/test.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/best_acc_top1_epoch_1.pth
# Out:
# 08/09 14:04:13 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: False
#     MUSA available: False
#     numpy_random_seed: 386764143
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.3.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
# ...

# %%
# !mim download mmaction2 --config tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb --dest .
# Out:
# Aborted!

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 26.3 MB/s eta 0:00:00
# ...

# %%
# !CUDA_VISIBLE_DEVICES=-1  python demo/demo.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    epoch_10.pth \
    /content/mmaction2/data/kinetics400/test/hammer_work1.mp4 /content/mmaction2/data/kinetics400/label_map_k2.txt
# Out:
# Loads checkpoint by local backend from path: epoch_10.pth
# 08/10 08:39:33 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/10 08:39:33 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# The top-5 labels with corresponding scores are:
# hammer_work:  0.9986976385116577
# pole_vaulting:  0.0013023626524955034

# %%
# !CUDA_VISIBLE_DEVICES=-1 python demo/demo.py work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    epoch_10.pth \
    data/kinetics400/test/pole_vaulting17.mp4 /content/mmaction2/data/kinetics400/label_map_k2.txt

# !CUDA_VISIBLE_DEVICES=-1  python demo/demo.py work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    epoch_10.pth \
    data/kinetics400/test/pole_vaulting2.mp4 /content/mmaction2/data/kinetics400/label_map_k2.txt
# Out:
# Loads checkpoint by local backend from path: epoch_10.pth
# 08/09 15:42:06 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/09 15:42:06 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# The top-5 labels with corresponding scores are:
# pole_vaulting:  1.0
# hammer_work:  1.4021766858718365e-08
# Loads checkpoint by local backend from path: epoch_10.pth
# 08/09 15:43:24 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/09 15:43:24 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# The top-5 labels with corresponding scores are:
# pole_vaulting:  0.9991891980171204
# hammer_work:  0.0008107533794827759

# %%
# !ls -l
# Out:
# total 279608
# -rw-r--r--  1 root root       297 Aug  8 16:04 CITATION.cff
# drwxr-xr-x 10 root root      4096 Aug  8 16:04 configs
# drwx------  3 root root      4096 Aug  8 16:10 data
# -rw-r--r--  1 root root       892 Aug  8 16:04 dataset-index.yml
# drwxr-xr-x  4 root root      4096 Aug  8 16:41 demo
# drwxr-xr-x  3 root root      4096 Aug  8 16:04 docker
# drwxr-xr-x  4 root root      4096 Aug  8 16:04 docs
# -rw-------  1 root root 188503664 Aug  7 14:28 epoch_10.pth
# -rw-r--r--  1 root root     11400 Aug  8 16:04 LICENSE
# -rw-r--r--  1 root root       177 Aug  8 16:04 MANIFEST.in
# drwxr-xr-x 14 root root      4096 Aug  8 16:08 mmaction
# drwxr-xr-x  2 root root      4096 Aug  8 16:04 mmaction2.egg-info
# -rw-r--r--  1 root root      1526 Aug  8 16:04 model-index.yml
# drwxr-xr-x 10 root root      4096 Aug  8 16:04 projects
# -rw-r--r--  1 root root     25956 Aug  8 16:04 README.md
# -rw-r--r--  1 root root     26412 Aug  8 16:04 README_zh-CN.md
# ...

# %%
# !pwd pole 254
# Out:
# /content/mmaction2

# %%
# !python demo/demo_inferencer.py  data/kinetics400/test/pole_vaulting17.mp4 \
    --vid-out-dir /content/mmaction2 \
    --rec tsn \
    --rec-weights /content/mmaction2/epoch_10.pth --print-result \
    --label-file /content/mmaction2/data/kinetics400/label_map_k2.txt \
    --show
# Out:
# Loads checkpoint by local backend from path: /content/mmaction2/epoch_10.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for cls_head.fc_cls.weight: copying a param with shape torch.Size([2, 2048]) from checkpoint, the shape in current model is torch.Size([400, 2048]).
# size mismatch for cls_head.fc_cls.bias: copying a param with shape torch.Size([2]) from checkpoint, the shape in current model is torch.Size([400]).
# /usr/local/lib/python3.10/dist-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmaction.visualization.video_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   08/16 14:24:03 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# ...

# %%
# !python demo/demo_inferencer.py  demo/demo.mp4 \
    --rec tsn --print-result \
    --label-file tools/data/kinetics/label_map_k400.txt
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmaction/v1.0/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb/tsn_imagenet-pretrained-r50_8xb32-1x1x8-100e_kinetics400-rgb_20220906-2692d16c.pth
# /usr/local/lib/python3.10/dist-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmaction.visualization.video_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   08/16 14:18:01 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/16 14:18:01 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...

# %%
# %cd mmaction2
# Out:
# /content/mmaction2
