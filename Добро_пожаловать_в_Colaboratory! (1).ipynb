# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv<2.2.0,>=2.0.0rc4
# !mim install mmdet<3.3.0,>=3.0.0
# !mim install mmpose
# Out:
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.4.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 14.5 MB/s eta 0:00:00
# ...
# /bin/bash: line 1: 2.2.0,: No such file or directory
# /bin/bash: line 1: 3.3.0,: No such file or directory
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.4.0/index.html
# ...
#   Using cached mmpose-1.3.2-py2.py3-none-any.whl.metadata (29 kB)
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# Ignoring mmdet: markers 'extra == "mim"' don't match your environment
# Ignoring mmengine: markers 'extra == "mim"' don't match your environment
# ...
#   Using cached chumpy-0.70.tar.gz (50 kB)
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 17.5 MB/s eta 0:00:00
# ...

# %%
# !mim install "mmcv>=2.0.0rc4, <2.2.0"
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.4.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.4/471.4 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mmcv: filename=mmcv-2.1.0-cp310-cp310-linux_x86_64.whl size=28676290 sha256=81e95d8838488140cf17a3894ce956bd4fdd77165e2329772c46af54df58200b
#   Stored in directory: /root/.cache/pip/wheels/8b/09/35/94a7f7ba6a00e3810abd0492340e4cbba0ff3d443120a94120
# Successfully built mmcv
# ...

# %% [markdown]
# # Новый раздел

# %%
# !git clone https://github.com/open-mmlab/mmaction2.git
# %cd mmaction2
# !pip install -v -e .
# Out:
# fatal: destination path 'mmaction2' already exists and is not an empty directory.
# /content/mmaction2
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content/mmaction2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-uzdf28my/mmaction2.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-uzdf28my/mmaction2.egg-info/SOURCES.txt'
# ...
#   writing manifest file '/tmp/pip-pip-egg-info-uzdf28my/mmaction2.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for decord>=0.4.1 from https://files.pythonhosted.org/packages/11/79/936af42edf90a7bd4e41a6cac89c913d4b47fa48a26b042d5129a9242ee3/decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 72.0 MB/s eta 0:00:00
# ...
#   Running setup.py develop for mmaction2
#     Running command python setup.py develop
#     running develop
# ...

# %%
# !pip install moviepy
# !python tools/visualizations/browse_dataset.py \
    /content/mmaction2/configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    browse_out --mode pipeline
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# [                                                  ] 0/4, elapsed: 0s, ETA:09/08 09:44:56 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 09/08 09:44:56 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...

# %%
# !pip install timm
# !python tools/visualizations/vis_scheduler.py \
    /content/mmaction2/configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# Param_scheduler :
# [
#   {
#     "type": "MultiStepLR",
#     "begin": 0,
#     "end": 10,
#     "by_epoch": true,
#     "milestones": [
#       4,
#       8
#     ],
#     "gamma": 0.1
#   }
# ]
#
# Dataset infos:
#  - Dataset size: 2
#  - Batch size per GPU: 2
#  - Number of GPUs: 1
#  - Total batch size: 2
#
# 09/08 09:46:17 - mmengine - WARNING - Dataset range has no metainfo. ``dataset_meta`` in visualizer will be None.
# /usr/local/lib/python3.10/dist-packages/mmengine/optim/scheduler/param_scheduler.py:198:
# ...
# later, you should call them in the opposite order: `optimizer.step()` before `scheduler.step()`.
# ...

# %%
! CUDA_VISIBLE_DEVICES=-1 python tools/train.py /content/mmaction2/configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py
# Out:
# /usr/local/lib/python3.10/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 09/08 09:46:31 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: False
#     MUSA available: False
#     numpy_random_seed: 1399028986
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.4.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
# ...

# %%
# !python tools/test.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/best_acc_top1_epoch_1.pth
# Out:
# /usr/local/lib/python3.10/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 09/08 10:36:29 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: False
#     MUSA available: False
#     numpy_random_seed: 1651820244
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.4.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
# ...

# %%
# !pip install timm

# %%
# !CUDA_VISIBLE_DEVICES=-1  python demo/demo.py configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb.py \
    /content/mmaction2/work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/epoch_100.pth \
    /content/mmaction2/run.mp4 /content/mmaction2/classes.txt
# Out:
# /usr/local/lib/python3.10/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# Loads checkpoint by local backend from path: /content/mmaction2/work_dirs/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_kinetics400-rgb/epoch_100.pth
# ...
