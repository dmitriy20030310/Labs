# %%
# !pip install torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
import torch

torch.cuda.is_available()
torch.cuda.current_device()
# Out:
# 0

# %%
# !pip install roboflow

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 7.0 MB/s eta 0:00:00
# ...

# %%
#TEST

from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-pose.pt')  # load an official model

# Predict with the model
model.predict('https://ultralytics.com/images/bus.jpg', save=True, imgsz=320, conf=0.5)
# Out:
# ...
# 100%|██████████| 6.51M/6.51M [00:00<00:00, 234MB/s]
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 55.5MB/s]
# image 1/1 /content/bus.jpg: 320x256 3 persons, 206.8ms
# Speed: 16.0ms preprocess, 206.8ms inference, 25.5ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to runs/pose/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
#  orig_img: array([[[122, 148, 172],
#          [120, 146, 170],
#          [125, 153, 177],
#          ...,
#          [157, 170, 184],
#          [158, 171, 185],
#          [158, 171, 185]],
#
#         [[127, 153, 177],
#          [124, 150, 174],
#          [127, 155, 179],
#          ...,
#          [158, 171, 185],
#          [159, 172, 186],
#          [159, 172, 186]],
#
#         [[128, 154, 178],
#          [126, 152, 176],
#          [126, 154, 178],
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TbWPOGFVnMi5i7XbLcme")
project = rf.workspace("sem2l1").project("goodpeople")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to goodPeople-1 in yolov5pytorch:: 100%|██████████| 996/996 [00:00<00:00, 2327.57it/s]

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import torch
import yaml

model = YOLO('yolov8-pose.yaml')


result = model.train(data='/content/goodPeople-1/data.yaml', epochs=400, imgsz=640, device=0)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b90f144f737a> in <cell line: 11>()
#       9
#      10
# ---> 11 yaml_content = model.yaml
#      12
#      13 # Вывод содержимого YAML файла
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1686             if name in modules:
#    1687                 return modules[name]
# -> 1688         raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#    1689
#    1690     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'YOLO' object has no attribute 'yaml'

# %%
from IPython.display import Image
Image('./runs/pose/train3/results.png')

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO('/content/best (1).pt')

model.predict('1.jpeg', save=True, imgsz=320, conf=0.5)
model.predict('2.jpg', save=True, imgsz=320, conf=0.5)
model.predict('3.jpeg', save=True, imgsz=320, conf=0.5)
model.predict('4.jpg', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/1.jpeg: 320x192 1 person, 74.4ms
# Speed: 1.3ms preprocess, 74.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 192)
# Results saved to runs/pose/predict3
#
# image 1/1 /content/2.jpg: 320x224 1 person, 59.1ms
# Speed: 1.3ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
# Results saved to runs/pose/predict3
#
# image 1/1 /content/3.jpeg: 320x256 1 person, 56.9ms
# Speed: 1.4ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to runs/pose/predict3
#
# image 1/1 /content/4.jpg: 320x320 1 person, 72.2ms
# Speed: 2.0ms preprocess, 72.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/pose/predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
# ...

# %%
from IPython.display import Image
Image('./runs/pose/predict3/1.jpeg')

# %%
Image('./runs/pose/predict3/2.jpg')

# %%
Image('./runs/pose/predict3/3.jpeg')

# %%
Image('./runs/pose/predict3/4.jpg')
